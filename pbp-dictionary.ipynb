# %% [markdown]
# # Total of 128651 entries, 353 players, 24 teams, 250 games

# %% [markdown]
# ## PBP Formatting
# * each entry tags (x,y) coordinates of one player only with one event
# * events involving multiple players (e.g. blocking fouls (shooter, fouler), blocked shot (shooter, blocker)) are listed as separate consecutive events
# * entries without applicable coordinates are given ('', '')
# * ~515 pbp events per game
# * (unconfirmed) 389 players from roster.csv - 353 players from pbp.csv = 36 players are in a roster yet they are never involved in a play. Probably means they got (almost) no playing time.
# * substitutions are logged (event_desc_id: 'IN', 'OUT')
# * missed/made shots and foul shots are described with totals (made/total) for the player in game
# * (unconfirmed) missed/total tallys are separated for types of shots (ft, 2pt, 3pt)
# * game_clock in minutes:seconds only

# %% [markdown]
# ### Build Dictionary

# %%
import csv

# %%
f = open('DataChallengeEuroGamePBP.csv', 'r')

f.seek(0)
s = f.read()
s = 'index' + s
f.close()

fout = open('pbp.csv', 'w')
fout.write(s)
fout.close()

# %%
f = open('pbp.csv', 'r')
reader = csv.DictReader(f, delimiter=',', quotechar='"')
pbp=[]
for line in reader:
    pbp.append(line)
f.close()

# %% [markdown]
# ### Housekeeping / Basic stats

# %%
len(pbp)
# Out:
# 128651

# %% [markdown]
# #### sample game

# %%
for i, p in enumerate(pbp):
    if p['gamecode'] == '125':
        print(i, p)
# Out:
# 63847 {'team_id': '', 'event_desc': 'Begin Period', 'index': '63847', 'coord_y': '', 'player_jersey_number': '', 'period': '1', 'event_desc_id': 'BP', 'pbp_id': '1', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': '', 'player_id': '', 'player_name': '', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '10:00'}
# 63848 {'team_id': 'BAM', 'event_desc': 'Assist (1)', 'index': '63848', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'AS', 'pbp_id': '2', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:56'}
# 63849 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (1)', 'index': '63849', 'coord_y': '', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '3', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:52'}
# 63850 {'team_id': 'MAD', 'event_desc': 'Foul (1)', 'index': '63850', 'coord_y': '', 'player_jersey_number': '44', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '4', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:43'}
# 63851 {'team_id': 'BAM', 'event_desc': 'Free Throw In (1/1 -  1 pt)', 'index': '63851', 'coord_y': '-1.0', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '5', 'score_visitor': '1.0', 'coord_x': '-1.0', 'score_home': '0.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:41'}
# 63852 {'team_id': 'BAM', 'event_desc': 'Free Throw In (2/2 -  2 pt)', 'index': '63852', 'coord_y': '-1.0', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '6', 'score_visitor': '2.0', 'coord_x': '-1.0', 'score_home': '0.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:41'}
# 63853 {'team_id': 'MAD', 'event_desc': 'Two Pointer (1/1 -  2 pt)', 'index': '63853', 'coord_y': '288.0', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '7', 'score_visitor': '2.0', 'coord_x': '-301.0', 'score_home': '2.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:18'}
# 63854 {'team_id': 'MAD', 'event_desc': 'Assist (1)', 'index': '63854', 'coord_y': '', 'player_jersey_number': '44', 'period': '1', 'event_desc_id': 'AS', 'pbp_id': '8', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:16'}
# 63855 {'team_id': 'BAM', 'event_desc': 'Missed Two Pointer (0/1 -  0 pt)', 'index': '63855', 'coord_y': '150.0', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '9', 'score_visitor': '2.0', 'coord_x': '-307.0', 'score_home': '2.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:10'}
# 63856 {'team_id': 'MAD', 'event_desc': 'Def Rebound (1)', 'index': '63856', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '10', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:07'}
# 63857 {'team_id': 'MAD', 'event_desc': 'Missed Three Pointer (0/1 -  0 pt)', 'index': '63857', 'coord_y': '564.0', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '11', 'score_visitor': '2.0', 'coord_x': '577.0', 'score_home': '2.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '2', 'seasoncode': 'E2015', 'game_clock': '08:50'}
# 63858 {'team_id': 'BAM', 'event_desc': 'Def Rebound (1)', 'index': '63858', 'coord_y': '', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '12', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '2', 'seasoncode': 'E2015', 'game_clock': '08:48'}
# 63859 {'team_id': 'BAM', 'event_desc': 'Three Pointer (1/1 -  3 pt)', 'index': '63859', 'coord_y': '608.0', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': '3FGM', 'pbp_id': '13', 'score_visitor': '5.0', 'coord_x': '432.0', 'score_home': '2.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '2', 'seasoncode': 'E2015', 'game_clock': '08:44'}
# 63860 {'team_id': 'MAD', 'event_desc': 'Missed Three Pointer (0/1 -  0 pt)', 'index': '63860', 'coord_y': '658.0', 'player_jersey_number': '8', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '14', 'score_visitor': '5.0', 'coord_x': '445.0', 'score_home': '2.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PJCC', 'player_name': 'MACIULIS, JONAS', 'game_minute': '2', 'seasoncode': 'E2015', 'game_clock': '08:18'}
# 63861 {'team_id': 'BAM', 'event_desc': 'Def Rebound (1)', 'index': '63861', 'coord_y': '', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '15', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '2', 'seasoncode': 'E2015', 'game_clock': '08:16'}
# 63862 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (1)', 'index': '63862', 'coord_y': '', 'player_jersey_number': '4', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '16', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P002849', 'player_name': 'MELLI, NICOLO', 'game_minute': '2', 'seasoncode': 'E2015', 'game_clock': '08:03'}
# 63863 {'team_id': 'MAD', 'event_desc': 'Foul (1)', 'index': '63863', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '17', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '2', 'seasoncode': 'E2015', 'game_clock': '08:03'}
# 63864 {'team_id': 'BAM', 'event_desc': 'Missed Two Pointer (0/1 -  0 pt)', 'index': '63864', 'coord_y': '43.0', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '18', 'score_visitor': '5.0', 'coord_x': '-401.0', 'score_home': '2.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:57'}
# 63865 {'team_id': 'MAD', 'event_desc': 'Def Rebound (1)', 'index': '63865', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '19', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:54'}
# 63866 {'team_id': 'MAD', 'event_desc': 'Two Pointer (1/1 -  2 pt)', 'index': '63866', 'coord_y': '-12.0', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '20', 'score_visitor': '5.0', 'coord_x': '12.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:40'}
# 63867 {'team_id': 'MAD', 'event_desc': 'Assist (1)', 'index': '63867', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'AS', 'pbp_id': '21', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:39'}
# 63868 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (1)', 'index': '63868', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '22', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:32'}
# 63869 {'team_id': 'MAD', 'event_desc': 'Foul (1)', 'index': '63869', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '23', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:32'}
# 63870 {'team_id': 'BAM', 'event_desc': 'Missed Two Pointer (0/1 -  2 pt)', 'index': '63870', 'coord_y': '100.0', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': '2FGAB', 'pbp_id': '24', 'score_visitor': '5.0', 'coord_x': '156.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:32'}
# 63871 {'team_id': 'BAM', 'event_desc': 'Shot Rejected (1)', 'index': '63871', 'coord_y': '', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'AG', 'pbp_id': '25', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:32'}
# 63872 {'team_id': 'MAD', 'event_desc': 'Block (1)', 'index': '63872', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'FV', 'pbp_id': '26', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:32'}
# 63873 {'team_id': 'BAM', 'event_desc': 'Off Rebound (1)', 'index': '63873', 'coord_y': '', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'O', 'pbp_id': '27', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:32'}
# 63874 {'team_id': 'BAM', 'event_desc': 'Missed Two Pointer (0/2 -  2 pt)', 'index': '63874', 'coord_y': '81.0', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '28', 'score_visitor': '5.0', 'coord_x': '-213.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:32'}
# 63875 {'team_id': 'MAD', 'event_desc': 'Def Rebound (1)', 'index': '63875', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '29', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:22'}
# 63876 {'team_id': 'MAD', 'event_desc': 'Missed Two Pointer (1/2 -  2 pt)', 'index': '63876', 'coord_y': '163.0', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '30', 'score_visitor': '5.0', 'coord_x': '276.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:16'}
# 63877 {'team_id': 'BAM', 'event_desc': 'Turnover (1)', 'index': '63877', 'coord_y': '', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': 'TO', 'pbp_id': '31', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:12'}
# 63878 {'team_id': 'MAD', 'event_desc': 'Steal (1)', 'index': '63878', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'ST', 'pbp_id': '32', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:10'}
# 63879 {'team_id': 'MAD', 'event_desc': 'Missed Two Pointer (0/1 -  0 pt)', 'index': '63879', 'coord_y': '376.0', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '33', 'score_visitor': '5.0', 'coord_x': '-225.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:07'}
# 63880 {'team_id': 'BAM', 'event_desc': 'Def Rebound (1)', 'index': '63880', 'coord_y': '', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '34', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:05'}
# 63881 {'team_id': 'BAM', 'event_desc': 'Two Pointer (1/3 -  4 pt)', 'index': '63881', 'coord_y': '238.0', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '35', 'score_visitor': '7.0', 'coord_x': '-363.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '3', 'seasoncode': 'E2015', 'game_clock': '07:00'}
# 63882 {'team_id': 'BAM', 'event_desc': 'Assist (2)', 'index': '63882', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'AS', 'pbp_id': '36', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '4', 'seasoncode': 'E2015', 'game_clock': '06:58'}
# 63883 {'team_id': 'MAD', 'event_desc': 'Missed Two Pointer (1/2 -  2 pt)', 'index': '63883', 'coord_y': '432.0', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '37', 'score_visitor': '7.0', 'coord_x': '-276.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '4', 'seasoncode': 'E2015', 'game_clock': '06:11'}
# 63884 {'team_id': 'BAM', 'event_desc': 'Def Rebound (1)', 'index': '63884', 'coord_y': '', 'player_jersey_number': '4', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '38', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P002849', 'player_name': 'MELLI, NICOLO', 'game_minute': '4', 'seasoncode': 'E2015', 'game_clock': '06:09'}
# 63885 {'team_id': 'BAM', 'event_desc': 'Missed Three Pointer (1/2 -  3 pt)', 'index': '63885', 'coord_y': '708.0', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '39', 'score_visitor': '7.0', 'coord_x': '181.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:45'}
# 63886 {'team_id': 'MAD', 'event_desc': 'Def Rebound (2)', 'index': '63886', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '40', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:43'}
# 63887 {'team_id': 'MAD', 'event_desc': 'Missed Two Pointer (0/1 -  0 pt)', 'index': '63887', 'coord_y': '12.0', 'player_jersey_number': '8', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '41', 'score_visitor': '7.0', 'coord_x': '-319.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PJCC', 'player_name': 'MACIULIS, JONAS', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:31'}
# 63888 {'team_id': 'BAM', 'event_desc': 'Def Rebound (2)', 'index': '63888', 'coord_y': '', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '42', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:29'}
# 63889 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (1)', 'index': '63889', 'coord_y': '', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '43', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:29'}
# 63890 {'team_id': 'MAD', 'event_desc': 'Foul (2)', 'index': '63890', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '44', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:29'}
# 63891 {'team_id': 'BAM', 'event_desc': 'In', 'index': '63891', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '45', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:27'}
# 63892 {'team_id': 'BAM', 'event_desc': 'In', 'index': '63892', 'coord_y': '', 'player_jersey_number': '10', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '46', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P004132', 'player_name': 'THEIS, DANIEL', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:27'}
# 63893 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '63893', 'coord_y': '', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '47', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:27'}
# 63894 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '63894', 'coord_y': '', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '48', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:27'}
# 63895 {'team_id': 'MAD', 'event_desc': 'In', 'index': '63895', 'coord_y': '', 'player_jersey_number': '7', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '49', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:27'}
# 63896 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '63896', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '50', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:27'}
# 63897 {'team_id': 'BAM', 'event_desc': 'Turnover (1)', 'index': '63897', 'coord_y': '', 'player_jersey_number': '4', 'period': '1', 'event_desc_id': 'TO', 'pbp_id': '51', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P002849', 'player_name': 'MELLI, NICOLO', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:08'}
# 63898 {'team_id': 'MAD', 'event_desc': 'Foul Drawn (1)', 'index': '63898', 'coord_y': '', 'player_jersey_number': '44', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '52', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:06'}
# 63899 {'team_id': 'BAM', 'event_desc': 'Foul (1)', 'index': '63899', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '53', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:06'}
# 63900 {'team_id': 'MAD', 'event_desc': 'Missed Two Pointer (0/1 -  0 pt)', 'index': '63900', 'coord_y': '426.0', 'player_jersey_number': '44', 'period': '1', 'event_desc_id': '2FGA', 'pbp_id': '54', 'score_visitor': '7.0', 'coord_x': '18.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:06'}
# 63901 {'team_id': 'BAM', 'event_desc': 'Def Rebound (2)', 'index': '63901', 'coord_y': '', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '55', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:06'}
# 63902 {'team_id': 'BAM', 'event_desc': 'Missed Three Pointer (0/1 -  0 pt)', 'index': '63902', 'coord_y': '765.0', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '56', 'score_visitor': '7.0', 'coord_x': '81.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:06'}
# 63903 {'team_id': 'MAD', 'event_desc': 'Def Rebound (3)', 'index': '63903', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '57', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:06'}
# 63904 {'team_id': 'MAD', 'event_desc': 'Turnover (1)', 'index': '63904', 'coord_y': '', 'player_jersey_number': '7', 'period': '1', 'event_desc_id': 'TO', 'pbp_id': '58', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '6', 'seasoncode': 'E2015', 'game_clock': '04:33'}
# 63905 {'team_id': 'BAM', 'event_desc': 'Steal (1)', 'index': '63905', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'ST', 'pbp_id': '59', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '6', 'seasoncode': 'E2015', 'game_clock': '04:32'}
# 63906 {'team_id': 'BAM', 'event_desc': 'Two Pointer (1/2 -  2 pt)', 'index': '63906', 'coord_y': '6.0', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '60', 'score_visitor': '9.0', 'coord_x': '-200.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '6', 'seasoncode': 'E2015', 'game_clock': '04:15'}
# 63907 {'team_id': 'MAD', 'event_desc': 'Missed Three Pointer (0/2 -  0 pt)', 'index': '63907', 'coord_y': '345.0', 'player_jersey_number': '8', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '61', 'score_visitor': '9.0', 'coord_x': '639.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PJCC', 'player_name': 'MACIULIS, JONAS', 'game_minute': '6', 'seasoncode': 'E2015', 'game_clock': '04:00'}
# 63908 {'team_id': 'BAM', 'event_desc': 'Def Rebound (1)', 'index': '63908', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '62', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:58'}
# 63909 {'team_id': 'BAM', 'event_desc': 'Two Pointer (1/2 -  2 pt)', 'index': '63909', 'coord_y': '25.0', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '63', 'score_visitor': '11.0', 'coord_x': '-175.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:54'}
# 63910 {'team_id': 'MAD', 'event_desc': 'Time Out (1)', 'index': '63910', 'coord_y': '', 'player_jersey_number': '', 'period': '1', 'event_desc_id': 'TOUT', 'pbp_id': '64', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': '', 'player_name': '', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:54'}
# 63911 {'team_id': 'MAD', 'event_desc': 'In', 'index': '63911', 'coord_y': '', 'player_jersey_number': '20', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '65', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:54'}
# 63912 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '63912', 'coord_y': '', 'player_jersey_number': '44', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '66', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:54'}
# 63913 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (2)', 'index': '63913', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '67', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:45'}
# 63914 {'team_id': 'MAD', 'event_desc': 'Turnover (1)', 'index': '63914', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'TO', 'pbp_id': '68', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:45'}
# 63915 {'team_id': 'MAD', 'event_desc': 'Offensive Foul (1)', 'index': '63915', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'OF', 'pbp_id': '69', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:45'}
# 63916 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (3)', 'index': '63916', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '70', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:32'}
# 63917 {'team_id': 'MAD', 'event_desc': 'Foul (2)', 'index': '63917', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '71', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:32'}
# 63918 {'team_id': 'MAD', 'event_desc': 'In', 'index': '63918', 'coord_y': '', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '72', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:30'}
# 63919 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '63919', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '73', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005836', 'player_name': 'THOMPKINS, TREY', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:30'}
# 63920 {'team_id': 'BAM', 'event_desc': 'Free Throw In (1/1 -  3 pt)', 'index': '63920', 'coord_y': '-1.0', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '74', 'score_visitor': '12.0', 'coord_x': '-1.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:30'}
# 63921 {'team_id': 'BAM', 'event_desc': 'Free Throw In (2/2 -  4 pt)', 'index': '63921', 'coord_y': '-1.0', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '75', 'score_visitor': '13.0', 'coord_x': '-1.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:30'}
# 63922 {'team_id': 'MAD', 'event_desc': 'Missed Three Pointer (0/1 -  0 pt)', 'index': '63922', 'coord_y': '539.0', 'player_jersey_number': '20', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '76', 'score_visitor': '13.0', 'coord_x': '-520.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:21'}
# 63923 {'team_id': 'MAD', 'event_desc': 'Off Rebound (1)', 'index': '63923', 'coord_y': '', 'player_jersey_number': '7', 'period': '1', 'event_desc_id': 'O', 'pbp_id': '77', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:21'}
# 63924 {'team_id': 'MAD', 'event_desc': 'Foul Drawn (1)', 'index': '63924', 'coord_y': '', 'player_jersey_number': '7', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '78', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:21'}
# 63925 {'team_id': 'BAM', 'event_desc': 'Foul (1)', 'index': '63925', 'coord_y': '', 'player_jersey_number': '4', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '79', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P002849', 'player_name': 'MELLI, NICOLO', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:21'}
# 63926 {'team_id': 'MAD', 'event_desc': 'Foul Drawn (1)', 'index': '63926', 'coord_y': '', 'player_jersey_number': '20', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '80', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:19'}
# 63927 {'team_id': 'BAM', 'event_desc': 'Foul (1)', 'index': '63927', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '81', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:19'}
# 63928 {'team_id': 'MAD', 'event_desc': 'Turnover (2)', 'index': '63928', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'TO', 'pbp_id': '82', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:11'}
# 63929 {'team_id': 'BAM', 'event_desc': 'In', 'index': '63929', 'coord_y': '', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '83', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:11'}
# 63930 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '63930', 'coord_y': '', 'player_jersey_number': '4', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '84', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P002849', 'player_name': 'MELLI, NICOLO', 'game_minute': '7', 'seasoncode': 'E2015', 'game_clock': '03:11'}
# 63931 {'team_id': 'BAM', 'event_desc': 'Missed Three Pointer (0/1 -  4 pt)', 'index': '63931', 'coord_y': '31.0', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '85', 'score_visitor': '13.0', 'coord_x': '-715.0', 'score_home': '4.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:49'}
# 63932 {'team_id': 'MAD', 'event_desc': 'Def Rebound (1)', 'index': '63932', 'coord_y': '', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '86', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:47'}
# 63933 {'team_id': 'MAD', 'event_desc': 'Foul Drawn (2)', 'index': '63933', 'coord_y': '', 'player_jersey_number': '7', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '87', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:46'}
# 63934 {'team_id': 'BAM', 'event_desc': 'Foul (1)', 'index': '63934', 'coord_y': '', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '88', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:46'}
# 63935 {'team_id': 'BAM', 'event_desc': 'In', 'index': '63935', 'coord_y': '', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '89', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:46'}
# 63936 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '63936', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '90', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PABN', 'player_name': 'ZISIS, NIKOS', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:46'}
# 63937 {'team_id': 'MAD', 'event_desc': 'Three Pointer (1/2 -  3 pt)', 'index': '63937', 'coord_y': '759.0', 'player_jersey_number': '20', 'period': '1', 'event_desc_id': '3FGM', 'pbp_id': '91', 'score_visitor': '13.0', 'coord_x': '-37.0', 'score_home': '7.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:39'}
# 63938 {'team_id': 'MAD', 'event_desc': 'Assist (1)', 'index': '63938', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'AS', 'pbp_id': '92', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:39'}
# 63939 {'team_id': 'BAM', 'event_desc': 'Missed Three Pointer (0/1 -  2 pt)', 'index': '63939', 'coord_y': '752.0', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '93', 'score_visitor': '13.0', 'coord_x': '-31.0', 'score_home': '7.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:39'}
# 63940 {'team_id': 'MAD', 'event_desc': 'Def Rebound (2)', 'index': '63940', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '94', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:19'}
# 63941 {'team_id': 'MAD', 'event_desc': 'Foul Drawn (1)', 'index': '63941', 'coord_y': '', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '95', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:19'}
# 63942 {'team_id': 'BAM', 'event_desc': 'Foul (1)', 'index': '63942', 'coord_y': '', 'player_jersey_number': '10', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '96', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P004132', 'player_name': 'THEIS, DANIEL', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:19'}
# 63943 {'team_id': 'MAD', 'event_desc': 'Free Throw In (1/1 -  1 pt)', 'index': '63943', 'coord_y': '-1.0', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '97', 'score_visitor': '13.0', 'coord_x': '-1.0', 'score_home': '8.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:17'}
# 63944 {'team_id': 'MAD', 'event_desc': 'Free Throw In (2/2 -  2 pt)', 'index': '63944', 'coord_y': '-1.0', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '98', 'score_visitor': '13.0', 'coord_x': '-1.0', 'score_home': '9.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:17'}
# 63945 {'team_id': 'BAM', 'event_desc': 'Two Pointer (2/4 -  6 pt)', 'index': '63945', 'coord_y': '-18.0', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '99', 'score_visitor': '15.0', 'coord_x': '420.0', 'score_home': '9.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:57'}
# 63946 {'team_id': 'BAM', 'event_desc': 'Assist (1)', 'index': '63946', 'coord_y': '', 'player_jersey_number': '13', 'period': '1', 'event_desc_id': 'AS', 'pbp_id': '100', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:55'}
# 63947 {'team_id': 'MAD', 'event_desc': 'Missed Three Pointer (0/1 -  0 pt)', 'index': '63947', 'coord_y': '771.0', 'player_jersey_number': '7', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '101', 'score_visitor': '15.0', 'coord_x': '6.0', 'score_home': '9.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:33'}
# 63948 {'team_id': 'BAM', 'event_desc': 'Def Rebound (3)', 'index': '63948', 'coord_y': '', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '102', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:31'}
# 63949 {'team_id': 'BAM', 'event_desc': 'Missed Three Pointer (0/1 -  0 pt)', 'index': '63949', 'coord_y': '621.0', 'player_jersey_number': '10', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '103', 'score_visitor': '15.0', 'coord_x': '464.0', 'score_home': '9.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P004132', 'player_name': 'THEIS, DANIEL', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:18'}
# 63950 {'team_id': 'MAD', 'event_desc': 'Def Rebound (2)', 'index': '63950', 'coord_y': '', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '104', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:15'}
# 63951 {'team_id': 'MAD', 'event_desc': 'Foul Drawn (2)', 'index': '63951', 'coord_y': '', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'RV', 'pbp_id': '105', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63952 {'team_id': 'BAM', 'event_desc': 'Foul (1)', 'index': '63952', 'coord_y': '', 'player_jersey_number': '43', 'period': '1', 'event_desc_id': 'CM', 'pbp_id': '106', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63953 {'team_id': 'MAD', 'event_desc': 'In', 'index': '63953', 'coord_y': '', 'player_jersey_number': '6', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '107', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAPR', 'player_name': 'NOCIONI, ANDRES', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63954 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '63954', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '108', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63955 {'team_id': 'MAD', 'event_desc': 'Free Throw In (3/3 -  3 pt)', 'index': '63955', 'coord_y': '-1.0', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '109', 'score_visitor': '15.0', 'coord_x': '-1.0', 'score_home': '10.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63956 {'team_id': 'MAD', 'event_desc': 'Free Throw In (4/4 -  4 pt)', 'index': '63956', 'coord_y': '-1.0', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': 'FTM', 'pbp_id': '110', 'score_visitor': '15.0', 'coord_x': '-1.0', 'score_home': '11.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63957 {'team_id': 'BAM', 'event_desc': 'In', 'index': '63957', 'coord_y': '', 'player_jersey_number': '33', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '111', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006420', 'player_name': 'HECKMANN, PATRICK', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63958 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '63958', 'coord_y': '', 'player_jersey_number': '21', 'period': '1', 'event_desc_id': 'OUT', 'pbp_id': '112', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006421', 'player_name': 'MILLER, DARIUS', 'game_minute': '9', 'seasoncode': 'E2015', 'game_clock': '01:05'}
# 63959 {'team_id': 'BAM', 'event_desc': 'Two Pointer (1/1 -  5 pt)', 'index': '63959', 'coord_y': '-12.0', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '113', 'score_visitor': '17.0', 'coord_x': '0.0', 'score_home': '11.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '10', 'seasoncode': 'E2015', 'game_clock': '00:47'}
# 63960 {'team_id': 'MAD', 'event_desc': 'Two Pointer (1/1 -  6 pt)', 'index': '63960', 'coord_y': '451.0', 'player_jersey_number': '9', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '114', 'score_visitor': '17.0', 'coord_x': '288.0', 'score_home': '13.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '10', 'seasoncode': 'E2015', 'game_clock': '00:31'}
# 63961 {'team_id': 'MAD', 'event_desc': 'Assist (1)', 'index': '63961', 'coord_y': '', 'player_jersey_number': '7', 'period': '1', 'event_desc_id': 'AS', 'pbp_id': '115', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '10', 'seasoncode': 'E2015', 'game_clock': '00:29'}
# 63962 {'team_id': 'BAM', 'event_desc': 'Two Pointer (2/2 -  7 pt)', 'index': '63962', 'coord_y': '106.0', 'player_jersey_number': '11', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '116', 'score_visitor': '19.0', 'coord_x': '213.0', 'score_home': '13.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '10', 'seasoncode': 'E2015', 'game_clock': '00:19'}
# 63963 {'team_id': 'MAD', 'event_desc': 'Missed Three Pointer (0/3 -  0 pt)', 'index': '63963', 'coord_y': '0.0', 'player_jersey_number': '8', 'period': '1', 'event_desc_id': '3FGA', 'pbp_id': '117', 'score_visitor': '19.0', 'coord_x': '715.0', 'score_home': '13.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PJCC', 'player_name': 'MACIULIS, JONAS', 'game_minute': '10', 'seasoncode': 'E2015', 'game_clock': '00:00'}
# ...
# 64355 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (6)', 'index': '64355', 'coord_y': '', 'player_jersey_number': '43', 'period': '4', 'event_desc_id': 'RV', 'pbp_id': '509', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:55'}
# 64356 {'team_id': 'MAD', 'event_desc': 'Foul (4)', 'index': '64356', 'coord_y': '', 'player_jersey_number': '14', 'period': '4', 'event_desc_id': 'CM', 'pbp_id': '510', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:55'}
# 64357 {'team_id': 'BAM', 'event_desc': 'In', 'index': '64357', 'coord_y': '', 'player_jersey_number': '4', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '511', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P002849', 'player_name': 'MELLI, NICOLO', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:44'}
# 64358 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '64358', 'coord_y': '', 'player_jersey_number': '13', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '512', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:44'}
# 64359 {'team_id': 'BAM', 'event_desc': 'Free Throw In (5/5 -  11 pt)', 'index': '64359', 'coord_y': '-1.0', 'player_jersey_number': '43', 'period': '4', 'event_desc_id': 'FTM', 'pbp_id': '513', 'score_visitor': '76.0', 'coord_x': '-1.0', 'score_home': '77.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:44'}
# 64360 {'team_id': 'BAM', 'event_desc': 'Free Throw In (6/6 -  12 pt)', 'index': '64360', 'coord_y': '-1.0', 'player_jersey_number': '43', 'period': '4', 'event_desc_id': 'FTM', 'pbp_id': '514', 'score_visitor': '77.0', 'coord_x': '-1.0', 'score_home': '77.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:44'}
# 64361 {'team_id': 'MAD', 'event_desc': 'In', 'index': '64361', 'coord_y': '', 'player_jersey_number': '20', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '515', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:44'}
# 64362 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '64362', 'coord_y': '', 'player_jersey_number': '44', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '516', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:44'}
# 64363 {'team_id': 'MAD', 'event_desc': 'Three Pointer (3/7 -  22 pt)', 'index': '64363', 'coord_y': '784.0', 'player_jersey_number': '13', 'period': '4', 'event_desc_id': '3FGM', 'pbp_id': '517', 'score_visitor': '77.0', 'coord_x': '-6.0', 'score_home': '80.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:42'}
# 64364 {'team_id': 'BAM', 'event_desc': 'In', 'index': '64364', 'coord_y': '', 'player_jersey_number': '13', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '518', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64365 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '64365', 'coord_y': '', 'player_jersey_number': '43', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '519', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64366 {'team_id': 'MAD', 'event_desc': 'In', 'index': '64366', 'coord_y': '', 'player_jersey_number': '44', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '520', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64367 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '64367', 'coord_y': '', 'player_jersey_number': '20', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '521', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64368 {'team_id': 'BAM', 'event_desc': 'Foul Drawn (3)', 'index': '64368', 'coord_y': '', 'player_jersey_number': '11', 'period': '4', 'event_desc_id': 'RV', 'pbp_id': '522', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64369 {'team_id': 'MAD', 'event_desc': 'Foul (1)', 'index': '64369', 'coord_y': '', 'player_jersey_number': '6', 'period': '4', 'event_desc_id': 'CM', 'pbp_id': '523', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAPR', 'player_name': 'NOCIONI, ANDRES', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64370 {'team_id': 'BAM', 'event_desc': 'Free Throw In (1/1 -  13 pt)', 'index': '64370', 'coord_y': '-1.0', 'player_jersey_number': '11', 'period': '4', 'event_desc_id': 'FTM', 'pbp_id': '524', 'score_visitor': '78.0', 'coord_x': '-1.0', 'score_home': '80.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64371 {'team_id': 'BAM', 'event_desc': 'Free Throw In (2/2 -  14 pt)', 'index': '64371', 'coord_y': '-1.0', 'player_jersey_number': '11', 'period': '4', 'event_desc_id': 'FTM', 'pbp_id': '525', 'score_visitor': '79.0', 'coord_x': '-1.0', 'score_home': '80.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64372 {'team_id': 'MAD', 'event_desc': 'Time Out (3)', 'index': '64372', 'coord_y': '', 'player_jersey_number': '', 'period': '4', 'event_desc_id': 'TOUT', 'pbp_id': '526', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': '', 'player_name': '', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64373 {'team_id': 'BAM', 'event_desc': 'In', 'index': '64373', 'coord_y': '', 'player_jersey_number': '43', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '527', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64374 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '64374', 'coord_y': '', 'player_jersey_number': '13', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '528', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64375 {'team_id': 'MAD', 'event_desc': 'In', 'index': '64375', 'coord_y': '', 'player_jersey_number': '9', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '529', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAAX', 'player_name': 'REYES, FELIPE', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64376 {'team_id': 'MAD', 'event_desc': 'In', 'index': '64376', 'coord_y': '', 'player_jersey_number': '20', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '530', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64377 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '64377', 'coord_y': '', 'player_jersey_number': '14', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '531', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005927', 'player_name': 'AYON, GUSTAVO', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64378 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '64378', 'coord_y': '', 'player_jersey_number': '44', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '532', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:21'}
# 64379 {'team_id': 'MAD', 'event_desc': 'Foul Drawn (2)', 'index': '64379', 'coord_y': '', 'player_jersey_number': '6', 'period': '4', 'event_desc_id': 'RV', 'pbp_id': '533', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAPR', 'player_name': 'NOCIONI, ANDRES', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64380 {'team_id': 'BAM', 'event_desc': 'Foul (5)', 'index': '64380', 'coord_y': '', 'player_jersey_number': '10', 'period': '4', 'event_desc_id': 'CM', 'pbp_id': '534', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P004132', 'player_name': 'THEIS, DANIEL', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64381 {'team_id': 'BAM', 'event_desc': 'In', 'index': '64381', 'coord_y': '', 'player_jersey_number': '13', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '535', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P000046', 'player_name': 'STRELNIEKS, JANIS', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64382 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '64382', 'coord_y': '', 'player_jersey_number': '10', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '536', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P004132', 'player_name': 'THEIS, DANIEL', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64383 {'team_id': 'MAD', 'event_desc': 'In', 'index': '64383', 'coord_y': '', 'player_jersey_number': '44', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '537', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P006546', 'player_name': 'TAYLOR, JEFFERY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64384 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '64384', 'coord_y': '', 'player_jersey_number': '13', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '538', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PCVM', 'player_name': 'RODRIGUEZ, SERGIO', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64385 {'team_id': 'BAM', 'event_desc': 'In', 'index': '64385', 'coord_y': '', 'player_jersey_number': '33', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '539', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P006420', 'player_name': 'HECKMANN, PATRICK', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64386 {'team_id': 'BAM', 'event_desc': 'Out', 'index': '64386', 'coord_y': '', 'player_jersey_number': '43', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '540', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'PLEM', 'player_name': 'RADOSEVIC, LEON', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64387 {'team_id': 'MAD', 'event_desc': 'In', 'index': '64387', 'coord_y': '', 'player_jersey_number': '7', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '541', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P005929', 'player_name': 'DONCIC, LUKA', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64388 {'team_id': 'MAD', 'event_desc': 'Out', 'index': '64388', 'coord_y': '', 'player_jersey_number': '20', 'period': '4', 'event_desc_id': 'OUT', 'pbp_id': '542', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'P001960', 'player_name': 'CARROLL, JAYCEE', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64389 {'team_id': 'MAD', 'event_desc': 'Free Throw In (1/1 -  8 pt)', 'index': '64389', 'coord_y': '-1.0', 'player_jersey_number': '6', 'period': '4', 'event_desc_id': 'FTM', 'pbp_id': '543', 'score_visitor': '79.0', 'coord_x': '-1.0', 'score_home': '81.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAPR', 'player_name': 'NOCIONI, ANDRES', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64390 {'team_id': 'MAD', 'event_desc': 'Free Throw In (2/2 -  9 pt)', 'index': '64390', 'coord_y': '-1.0', 'player_jersey_number': '6', 'period': '4', 'event_desc_id': 'FTM', 'pbp_id': '544', 'score_visitor': '79.0', 'coord_x': '-1.0', 'score_home': '82.0', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAPR', 'player_name': 'NOCIONI, ANDRES', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:08'}
# 64391 {'team_id': 'BAM', 'event_desc': 'Missed Three Pointer (2/7 -  14 pt)', 'index': '64391', 'coord_y': '740.0', 'player_jersey_number': '11', 'period': '4', 'event_desc_id': '3FGA', 'pbp_id': '545', 'score_visitor': '79.0', 'coord_x': '294.0', 'score_home': '82.0', 'gamecode': '125', 'team_name': 'Brose Baskets Bamberg', 'player_id': 'P005838', 'player_name': 'WANAMAKER, BRADLEY', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:00'}
# 64392 {'team_id': 'MAD', 'event_desc': 'Def Rebound (2)', 'index': '64392', 'coord_y': '', 'player_jersey_number': '6', 'period': '4', 'event_desc_id': 'D', 'pbp_id': '546', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': 'Real Madrid', 'player_id': 'PAPR', 'player_name': 'NOCIONI, ANDRES', 'game_minute': '40', 'seasoncode': 'E2015', 'game_clock': '00:00'}
# 64393 {'team_id': '', 'event_desc': 'End Game', 'index': '64393', 'coord_y': '', 'player_jersey_number': '', 'period': '4', 'event_desc_id': 'EG', 'pbp_id': '547', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '125', 'team_name': '', 'player_id': '', 'player_name': '', 'game_minute': '41', 'seasoncode': 'E2015', 'game_clock': '00:00'}

# %%
gamecodes=[]
for r in pbp:
    if r['gamecode'] not in gamecodes:
        gamecodes.append(r['gamecode'])
print(len(gamecodes))
# Out:
# 250

# %% [markdown]
# #### 24 teams + '' team for team-neutral events (e.g. start of period)

# %%
teamids=[]
for r in pbp:
    if r['team_id'] not in teamids:
        teamids.append(r['team_id'])
len(teamids)
# Out:
# 25

# %% [markdown]
# #### 353 players + '' player for events with no involved players (353 is not confirmed)

# %%
playerids=[]
for r in pbp:
    if r['player_id'] not in playerids:
        playerids.append(r['player_id'])
len(playerids)
# Out:
# 354

# %%
playernames=[]
for r in pbp:
    if r['player_name'] not in playernames:
        playernames.append(r['player_name'])
len(playernames)
# Out:
# 355

# %%
idnames=[]
for r in pbp:
    if (r['player_id'], r['player_name']) not in idnames:
        idnames.append((r['player_id'], r['player_name']))
len(idnames)
# Out:
# 358

# %%
dupeids = set([id for id in [idname[0] for idname in idnames] if [idname[0] for idname in idnames].count(id) > 1])
print(dupeids)
# Out:
# {'P004264', 'P005983', 'P001389', 'P005367'}

# %%
dupenames = set([player for player in [idname[1] for idname in idnames] if [idname[1] for idname in idnames].count(player) > 1])
print(dupenames)
# Out:
# {'', 'YURTSEVEN, OMER'}

# %%
for d in dupenames:
    temp=[]
    for r in pbp:
        if r['player_name'] == d:
            if r['player_id'] not in temp:
                temp.append(r['player_id'])
                print(r)
    print('-'*30)
# Out:
# {'team_id': '', 'event_desc': 'Begin Period', 'index': '0', 'coord_y': '', 'player_jersey_number': '', 'period': '1', 'event_desc_id': 'BP', 'pbp_id': '1', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '1', 'team_name': '', 'player_id': '', 'player_name': '', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '10:00'}
# {'team_id': 'MAD', 'event_desc': 'Coach Foul (1)', 'index': '309', 'coord_y': '', 'player_jersey_number': '', 'period': '3', 'event_desc_id': 'C', 'pbp_id': '310', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '1', 'team_name': 'Real Madrid', 'player_id': 'CO_B', 'player_name': '', 'game_minute': '26', 'seasoncode': 'E2015', 'game_clock': '04:59'}
# {'team_id': 'PAN', 'event_desc': 'Coach Foul (1)', 'index': '10355', 'coord_y': '', 'player_jersey_number': '', 'period': '4', 'event_desc_id': 'C', 'pbp_id': '455', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '20', 'team_name': 'Panathinaikos Athens', 'player_id': 'CO_A', 'player_name': '', 'game_minute': '38', 'seasoncode': 'E2015', 'game_clock': '02:59'}
# ------------------------------
# {'team_id': 'ULK', 'event_desc': 'In', 'index': '6846', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '97', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '14', 'team_name': 'Fenerbahce Istanbul', 'player_id': 'P005983', 'player_name': 'YURTSEVEN, OMER', 'game_minute': '10', 'seasoncode': 'E2015', 'game_clock': '00:30'}
# {'team_id': 'ULK', 'event_desc': 'In', 'index': '20110', 'coord_y': '', 'player_jersey_number': '14', 'period': '3', 'event_desc_id': 'IN', 'pbp_id': '362', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '39', 'team_name': 'Fenerbahce Istanbul', 'player_id': 'P005353', 'player_name': 'YURTSEVEN, OMER', 'game_minute': '30', 'seasoncode': 'E2015', 'game_clock': '00:49'}
# ------------------------------

# %%
for d in dupeids:
    temp=[]
    for r in pbp:
        if r['player_id'] == d:
            if r['player_name'] not in temp:
                temp.append(r['player_name'])
                print(r)
    print('-'*30)
# Out:
# {'team_id': 'GSS', 'event_desc': 'In', 'index': '3133', 'coord_y': '', 'player_jersey_number': '1', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '48', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '7', 'team_name': 'Stelmet Zielona Gora', 'player_id': 'P004264', 'player_name': 'BOST, DEMARQUIS', 'game_minute': '6', 'seasoncode': 'E2015', 'game_clock': '04:40'}
# {'team_id': 'GSS', 'event_desc': 'In', 'index': '9449', 'coord_y': '', 'player_jersey_number': '1', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '73', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '19', 'team_name': 'Stelmet Zielona Gora', 'player_id': 'P004264', 'player_name': 'BOST, DEE', 'game_minute': '8', 'seasoncode': 'E2015', 'game_clock': '02:40'}
# ------------------------------
# {'team_id': 'ULK', 'event_desc': 'In', 'index': '1049', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '25', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '3', 'team_name': 'Fenerbahce Istanbul', 'player_id': 'P005983', 'player_name': 'YURTSEVEN, OMER FARUK', 'game_minute': '4', 'seasoncode': 'E2015', 'game_clock': '06:47'}
# {'team_id': 'ULK', 'event_desc': 'In', 'index': '6846', 'coord_y': '', 'player_jersey_number': '14', 'period': '1', 'event_desc_id': 'IN', 'pbp_id': '97', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '14', 'team_name': 'Fenerbahce Istanbul', 'player_id': 'P005983', 'player_name': 'YURTSEVEN, OMER', 'game_minute': '10', 'seasoncode': 'E2015', 'game_clock': '00:30'}
# ------------------------------
# {'team_id': 'TIV', 'event_desc': 'Def Rebound (1)', 'index': '3616', 'coord_y': '', 'player_jersey_number': '18', 'period': '1', 'event_desc_id': 'D', 'pbp_id': '7', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '8', 'team_name': 'Lokomotiv Kuban Krasnodar', 'player_id': 'P001389', 'player_name': 'VORONOV, EUGENY', 'game_minute': '1', 'seasoncode': 'E2015', 'game_clock': '09:17'}
# {'team_id': 'TIV', 'event_desc': 'Two Pointer (1/1 -  2 pt)', 'index': '10447', 'coord_y': '156.0', 'player_jersey_number': '18', 'period': '1', 'event_desc_id': '2FGM', 'pbp_id': '50', 'score_visitor': '15.0', 'coord_x': '-125.0', 'score_home': '16.0', 'gamecode': '21', 'team_name': 'Lokomotiv Kuban Krasnodar', 'player_id': 'P001389', 'player_name': 'VORONOV, EVGENY', 'game_minute': '5', 'seasoncode': 'E2015', 'game_clock': '05:03'}
# ------------------------------
# {'team_id': 'MAL', 'event_desc': 'In', 'index': '48250', 'coord_y': '', 'player_jersey_number': '3', 'period': '2', 'event_desc_id': 'IN', 'pbp_id': '138', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '94', 'team_name': 'Unicaja Malaga', 'player_id': 'P005367', 'player_name': 'UTA, RARES', 'game_minute': '15', 'seasoncode': 'E2015', 'game_clock': '05:56'}
# {'team_id': 'MAL', 'event_desc': 'In', 'index': '86942', 'coord_y': '', 'player_jersey_number': '3', 'period': '4', 'event_desc_id': 'IN', 'pbp_id': '475', 'score_visitor': '', 'coord_x': '', 'score_home': '', 'gamecode': '169', 'team_name': 'Unicaja Malaga', 'player_id': 'P005367', 'player_name': 'UTA, CHISTIAN', 'game_minute': '39', 'seasoncode': 'E2015', 'game_clock': '01:30'}
# ------------------------------

# %%
event_desc=[]
for r in pbp:
    if r['event_desc'] not in event_desc:
        event_desc.append(r['event_desc'])
len(event_desc)
# Out:
# 3114

# %%
event_desc_id=[]
for r in pbp:
    if r['event_desc_id'] not in event_desc_id:
        event_desc_id.append(r['event_desc_id'])
print(len(event_desc_id))
print(event_desc_id)
# Out:
# 29
# ['BP', '2FGAB', 'AG', 'FV', 'D', '3FGA', 'O', 'TO', '2FGA', '3FGM', 'AS', 'ST', 'RV', 'CM', 'IN', 'OUT', '2FGM', 'OF', 'TOUT_TV', 'FTA', 'FTM', '3FGAB', 'TOUT', 'C', 'CMU', 'CMT', 'EG', 'B', 'CMD']

# %% [raw]
# ### event_desc_id
# BP, begin period
# 2FGAB, missed two pointer blocked
# AG, shot rejected
# FV, block
# D, def rebound
# 3FGA, missed three pointer
# O, off rebound
# TO, turnover
# 2FGA, missed two pointer
# 3FGM, three pointer
# AS, assist
# ST, steal
# RV, foul drawn
# CM, foul
# IN, substitution in
# OUT, substitution out
# 2FGM, two pointer
# OF, offensive foul
# TOUT_TV, tv time out
# FTA, missed free throw
# FTM, made free throw
# 3FGAB, missed three pointer blocked
# TOUT, time out
# C, coach foul
# CMU, unsportsmanlike foul
# CMT, technical foul
# EG, end game
# B, bench foul
# CMD, disqualifying foul

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Identify the top 5 teams & players in offensive rebounding. Describe the metric(s) used and explain why you used it.

# %% [raw]
# offensive rebounding percentage (orebs / missed shots)
# drawing loose ball fouls after own team's missed shots
# was a player in play when a team missed a shot? (we can find out based on substitutions)

# %%
orebs_player = {}
orebs_team = {}
missedshots_team = {}
for r in pbp:
    if r['event_desc_id'] == 'O':
        if r['player_id'] not in orebs_player.keys():
            orebs_player[r['player_id']] = []
        orebs_player[r['player_id']].append(r)
        if r['team_id'] not in orebs_team.keys():
            orebs_team[r['team_id']] = []
        orebs_team[r['team_id']].append(r)
    elif any([r['event_desc_id'] == e for e in ('2FGA', '2FGAB', '3FGA', '3FGAB')]):
        #consider last missed free throw
        if r['team_id'] not in missedshots_team.keys():
            missedshots_team[r['team_id']] = []
        missedshots_team[r['team_id']].append(r)
        
for key, value in orebs_team.items():
    print(key, len(value), '/', len(missedshots_team[key]))
# Out:
# MUN 99 / 350
# TEL 123 / 356
# MAD 312 / 942
# PAN 278 / 856
# KHI 272 / 831
# RED 282 / 864
# TIV 331 / 1022
# KSK 94 / 345
# SAS 75 / 346
# ZAL 244 / 824
# CED 236 / 795
# MIL 107 / 367
# GSS 102 / 344
# ULK 303 / 925
# IST 276 / 791
# DAR 237 / 769
# BAM 186 / 716
# LMG 87 / 309
# STR 99 / 344
# CSK 277 / 843
# OLY 283 / 836
# BAR 283 / 929
# MAL 313 / 821
# BAS 297 / 1012
